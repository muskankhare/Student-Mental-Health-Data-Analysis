# %% [markdown]
# ### ***Student Mental Health Data Analysis***

# %% [markdown]
# ####***Team Members***
#
# > **Isha Rakesh Motiyani (202218015)**
#
# > **Muskan Khare (202218037)**
#
# > **Chinmaya Pandey (202218054)**

# %% [markdown]
# ### Importing Required Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

import os

import plotly.offline as pyo
import plotly.graph_objs as go
import plotly.offline as py
from plotly import tools
from plotly.offline import iplot

import warnings
warnings.filterwarnings("ignore")
import cufflinks as cf
cf.go_offline()
import plotly.io as pio
pio.renderers.default='colab'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Opening the csv file containing DataSet

# %%
data = pd.read_csv('/content/Student Mental Health Survey.csv')

# %%
data
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 0       08-07-2020 12:02             Female  18.0          Engineering
# 1       08-07-2020 12:04               Male  21.0             Pharmacy
# 2       08-07-2020 12:05               Male  19.0                   IT
# 3       08-07-2020 12:06             Female  22.0                  Law
# 4       08-07-2020 12:13               male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 298  11/13/2022 16:27:11             Female  27.0             Pharmacy
# 299  11/13/2022 16:28:01             Female  26.0           Psychology
# 300  11/13/2022 16:28:01             Female  21.0             Pharmacy
# 301  11/13/2022 16:29:21             Female  23.0          Mathematics
# 302  11/13/2022 16:29:29               Male  28.0           Psychology
#
#     Your current year of Study  What is your CGPA? Marital status  \
# 0                       year 1                 7.0             No
# 1                       year 2                 8.0             No
# 2                       Year 1                 4.0             No
# 3                       year 3                 5.0            Yes
# 4                       year 4                 8.0             No
# ..                         ...                 ...            ...
# 298                     Year 2                 7.0            Yes
# 299                     Year 2                 8.0            Yes
# 300                     Year 2                 9.0             No
# 301                     Year 3                 6.0             No
# 302                     Year 2                 7.0            Yes
#
#     Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                       Yes                   No                       Yes
# 1                        No                  Yes                        No
# 2                       Yes                  Yes                       Yes
# 3                       Yes                   No                        No
# 4                        No                   No                        No
# ..                      ...                  ...                       ...
# 298                      No                  Yes                       Yes
# 299                     Yes                   No                        No
# 300                      No                   No                        No
# 301                     Yes                   No                       Yes
# 302                      No                  Yes                       Yes
#
#     Did you seek any specialist for a treatment?
# 0                                             No
# 1                                             No
# 2                                             No
# 3                                             No
# 4                                             No
# ..                                           ...
# 298                                          Yes
# 299                                          Yes
# 300                                           No
# 301                                          Yes
# 302                                          Yes
#
# [303 rows x 11 columns]

# %%
data.shape
# Out:
# (303, 11)

# %% [markdown]
# ###***Cleaning the DataSet***

# %% [markdown]
# ###Dropping rows containing null values

# %%
data = data.dropna()

# %%
data
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 0       08-07-2020 12:02             Female  18.0          Engineering
# 1       08-07-2020 12:04               Male  21.0             Pharmacy
# 2       08-07-2020 12:05               Male  19.0                   IT
# 3       08-07-2020 12:06             Female  22.0                  Law
# 4       08-07-2020 12:13               male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 298  11/13/2022 16:27:11             Female  27.0             Pharmacy
# 299  11/13/2022 16:28:01             Female  26.0           Psychology
# 300  11/13/2022 16:28:01             Female  21.0             Pharmacy
# 301  11/13/2022 16:29:21             Female  23.0          Mathematics
# 302  11/13/2022 16:29:29               Male  28.0           Psychology
#
#     Your current year of Study  What is your CGPA? Marital status  \
# 0                       year 1                 7.0             No
# 1                       year 2                 8.0             No
# 2                       Year 1                 4.0             No
# 3                       year 3                 5.0            Yes
# 4                       year 4                 8.0             No
# ..                         ...                 ...            ...
# 298                     Year 2                 7.0            Yes
# 299                     Year 2                 8.0            Yes
# 300                     Year 2                 9.0             No
# 301                     Year 3                 6.0             No
# 302                     Year 2                 7.0            Yes
#
#     Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                       Yes                   No                       Yes
# 1                        No                  Yes                        No
# 2                       Yes                  Yes                       Yes
# 3                       Yes                   No                        No
# 4                        No                   No                        No
# ..                      ...                  ...                       ...
# 298                      No                  Yes                       Yes
# 299                     Yes                   No                        No
# 300                      No                   No                        No
# 301                     Yes                   No                       Yes
# 302                      No                  Yes                       Yes
#
#     Did you seek any specialist for a treatment?
# 0                                             No
# 1                                             No
# 2                                             No
# 3                                             No
# 4                                             No
# ..                                           ...
# 298                                          Yes
# 299                                          Yes
# 300                                           No
# 301                                          Yes
# 302                                          Yes
#
# [298 rows x 11 columns]

# %%
data.shape
# Out:
# (298, 11)

# %% [markdown]
# ###Renaming columns

# %%
data.rename(columns = {'Choose your gender':'Gender',
                     'What is your course?':'Course', 
                     'Your current year of Study': 'Year',
                     'What is your CGPA?': 'CGPA',
                     'Marital status': 'Married',
                     'Do you have Depression?': 'Depression',
                     'Do you have Anxiety?': 'Anxiety',
                     'Do you have Panic attack?': 'Panic Attack',
                     'Did you seek any specialist for a treatment?': 'Seeking Treatment'},inplace = True)

# %%
data
# Out:
#                Timestamp  Gender   Age        Course    Year  CGPA Married  \
# 0       08-07-2020 12:02  Female  18.0   Engineering  year 1   7.0      No
# 1       08-07-2020 12:04    Male  21.0      Pharmacy  year 2   8.0      No
# 2       08-07-2020 12:05    Male  19.0            IT  Year 1   4.0      No
# 3       08-07-2020 12:06  Female  22.0           Law  year 3   5.0     Yes
# 4       08-07-2020 12:13    male  23.0  Mathemathics  year 4   8.0      No
# ..                   ...     ...   ...           ...     ...   ...     ...
# 298  11/13/2022 16:27:11  Female  27.0      Pharmacy  Year 2   7.0     Yes
# 299  11/13/2022 16:28:01  Female  26.0    Psychology  Year 2   8.0     Yes
# 300  11/13/2022 16:28:01  Female  21.0      Pharmacy  Year 2   9.0      No
# 301  11/13/2022 16:29:21  Female  23.0   Mathematics  Year 3   6.0      No
# 302  11/13/2022 16:29:29    Male  28.0    Psychology  Year 2   7.0     Yes
#
#     Depression Anxiety Panic Attack Seeking Treatment
# 0          Yes      No          Yes                No
# 1           No     Yes           No                No
# 2          Yes     Yes          Yes                No
# 3          Yes      No           No                No
# 4           No      No           No                No
# ..         ...     ...          ...               ...
# 298         No     Yes          Yes               Yes
# 299        Yes      No           No               Yes
# 300         No      No           No                No
# 301        Yes      No          Yes               Yes
# 302         No     Yes          Yes               Yes
#
# [298 rows x 11 columns]

# %% [markdown]
# ###Removing unnecessary columns from the DataSet

# %%
data = data.drop(columns = "Timestamp")
data
# Out:
#      Gender   Age        Course    Year  CGPA Married Depression Anxiety  \
# 0    Female  18.0   Engineering  year 1   7.0      No        Yes      No
# 1      Male  21.0      Pharmacy  year 2   8.0      No         No     Yes
# 2      Male  19.0            IT  Year 1   4.0      No        Yes     Yes
# 3    Female  22.0           Law  year 3   5.0     Yes        Yes      No
# 4      male  23.0  Mathemathics  year 4   8.0      No         No      No
# ..      ...   ...           ...     ...   ...     ...        ...     ...
# 298  Female  27.0      Pharmacy  Year 2   7.0     Yes         No     Yes
# 299  Female  26.0    Psychology  Year 2   8.0     Yes        Yes      No
# 300  Female  21.0      Pharmacy  Year 2   9.0      No         No      No
# 301  Female  23.0   Mathematics  Year 3   6.0      No        Yes      No
# 302    Male  28.0    Psychology  Year 2   7.0     Yes         No     Yes
#
#     Panic Attack Seeking Treatment
# 0            Yes                No
# 1             No                No
# 2            Yes                No
# 3             No                No
# 4             No                No
# ..           ...               ...
# 298          Yes               Yes
# 299           No               Yes
# 300           No                No
# 301          Yes               Yes
# 302          Yes               Yes
#
# [298 rows x 10 columns]

# %% [markdown]
# ###Cleaning data for particular columns

# %% [markdown]
# ###--> Cleaning Gender column

# %%
# Proper case formatting of gender column
data['Gender'] = data['Gender'].str.title()
data
# Out:
#      Gender   Age        Course    Year  CGPA Married Depression Anxiety  \
# 0    Female  18.0   Engineering  year 1   7.0      No        Yes      No
# 1      Male  21.0      Pharmacy  year 2   8.0      No         No     Yes
# 2      Male  19.0            IT  Year 1   4.0      No        Yes     Yes
# 3    Female  22.0           Law  year 3   5.0     Yes        Yes      No
# 4      Male  23.0  Mathemathics  year 4   8.0      No         No      No
# ..      ...   ...           ...     ...   ...     ...        ...     ...
# 298  Female  27.0      Pharmacy  Year 2   7.0     Yes         No     Yes
# 299  Female  26.0    Psychology  Year 2   8.0     Yes        Yes      No
# 300  Female  21.0      Pharmacy  Year 2   9.0      No         No      No
# 301  Female  23.0   Mathematics  Year 3   6.0      No        Yes      No
# 302    Male  28.0    Psychology  Year 2   7.0     Yes         No     Yes
#
#     Panic Attack Seeking Treatment
# 0            Yes                No
# 1             No                No
# 2            Yes                No
# 3             No                No
# 4             No                No
# ..           ...               ...
# 298          Yes               Yes
# 299           No               Yes
# 300           No                No
# 301          Yes               Yes
# 302          Yes               Yes
#
# [298 rows x 10 columns]

# %% [markdown]
# ###--> Cleaning Course column

# %%
data['Course'].unique()
# Out:
# array(['Engineering', 'Pharmacy', 'IT', 'Law', 'Mathemathics',
#        'Human Resources', 'Humanities', 'Psychology', 'Mathematics',
#        'pharmacy', 'medical', 'it', 'humanities', 'Data Science',
#        'engineering', 'Management', 'Medical', 'Engine', 'psychology',
#        'Biomedical science', 'engin', 'maths', 'biology', 'Laws',
#        'Biotechnology', 'Diploma Nursing', 'law', 'Nursing '],
#       dtype=object)

# %%
# Providing proper case formatting to the course column
data['Course'] = data['Course'].str.title()
data['Course'].unique()
# Out:
# array(['Engineering', 'Pharmacy', 'It', 'Law', 'Mathemathics',
#        'Human Resources', 'Humanities', 'Psychology', 'Mathematics',
#        'Medical', 'Data Science', 'Management', 'Engine',
#        'Biomedical Science', 'Engin', 'Maths', 'Biology', 'Laws',
#        'Biotechnology', 'Diploma Nursing', 'Nursing '], dtype=object)

# %%
# Merging related or same courses
data['Course'].replace({'Mathemathics': 'Mathematics',
                      'Maths': 'Mathematics',
                      'Human Resources': 'Humanities',
                      'Biomedical Science': 'Medical',
                      'Biotechnology': 'Medical',
                      'Biology': 'Medical',
                      'Diploma Nursing': 'Medical',
                      'Nursing ': 'Medical',
                      'Engine': 'Engineering',
                      'Engin': 'Engineering',
                      'Laws': 'Law',
                      'It': 'IT'}, inplace=True)

data['Course'].unique()
# Out:
# array(['Engineering', 'Pharmacy', 'IT', 'Law', 'Mathematics',
#        'Humanities', 'Psychology', 'Medical', 'Data Science',
#        'Management'], dtype=object)

# %% [markdown]
# ###--> Cleaning Year column

# %%
# getting unique years
data['Year'].unique()
# Out:
# array(['year 1', 'year 2', 'Year 1', 'year 3', 'year 4', 'Year 2',
#        'Year 3', 'Year 4', 'Year 5'], dtype=object)

# %%
# Case formatting for Year column
data['Year'] = data['Year'].str.title()
data['Year'].unique()
# Out:
# array(['Year 1', 'Year 2', 'Year 3', 'Year 4', 'Year 5'], dtype=object)

# %%
# Replacing string data in year column with numerical data
data['Year'].replace({'Year 1': 1,
                      'Year 2': 2,
                      'Year 3': 3,
                      'Year 4': 4,
                      'Year 5': 5}, inplace=True)
data['Year'].unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
data
# Out:
#      Gender   Age       Course  Year  CGPA Married Depression Anxiety  \
# 0    Female  18.0  Engineering     1   7.0      No        Yes      No
# 1      Male  21.0     Pharmacy     2   8.0      No         No     Yes
# 2      Male  19.0           IT     1   4.0      No        Yes     Yes
# 3    Female  22.0          Law     3   5.0     Yes        Yes      No
# 4      Male  23.0  Mathematics     4   8.0      No         No      No
# ..      ...   ...          ...   ...   ...     ...        ...     ...
# 298  Female  27.0     Pharmacy     2   7.0     Yes         No     Yes
# 299  Female  26.0   Psychology     2   8.0     Yes        Yes      No
# 300  Female  21.0     Pharmacy     2   9.0      No         No      No
# 301  Female  23.0  Mathematics     3   6.0      No        Yes      No
# 302    Male  28.0   Psychology     2   7.0     Yes         No     Yes
#
#     Panic Attack Seeking Treatment
# 0            Yes                No
# 1             No                No
# 2            Yes                No
# 3             No                No
# 4             No                No
# ..           ...               ...
# 298          Yes               Yes
# 299           No               Yes
# 300           No                No
# 301          Yes               Yes
# 302          Yes               Yes
#
# [298 rows x 10 columns]

# %% [markdown]
# ###***Data Analysis***

# %% [markdown]
# ### **Gender Distribution**

# %%
# counting gender distribution of all the surveyed data
gender = data['Gender'].value_counts()
gender_data = pd.DataFrame({'gender':gender.index , 'Number of students':gender.values})
gender_data
# Out:
#    gender  Number of students
# 0  Female                 172
# 1    Male                 126

# %%
# plotting a pie chart for the data calculated in the above mentioned snippet
gender_data.iplot(kind='pie',labels='gender',values='Number of students',title="Gender Distribution",hole=0.4)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0fdc2604-e1bb-4e93-8909-4bbc0d5ddfd6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("0fdc2604-e1bb-4e93-8909-4bbc0d5ddfd6")) {                    Plotly.newPlot(                        "0fdc2604-e1bb-4e93-8909-4bbc0d5ddfd6",                        [{"hole":0.4,"labels":["Female","Male"],"marker":{"colors":["rgba(255, 153, 51, 1.0)","rgba(55, 128, 191, 1.0)"]},"name":"","values":[172,126],"type":"pie"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","titlefont":{"color":"#4D5663"},"title":"Gender Distribution"},                        {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('0fdc2604-e1bb-4e93-8909-4bbc0d5ddfd6');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %% [markdown]
# ### **Course Distribution**

# %%
# Calculating number of students per course
course = data['Course'].value_counts()
course_data = pd.DataFrame({'course':course.index , 'Number of students':course.values})
course_data
# Out:
#          course  Number of students
# 0            IT                  61
# 1  Data Science                  52
# 2   Engineering                  42
# 3       Medical                  34
# 4   Mathematics                  31
# 5    Psychology                  25
# 6      Pharmacy                  23
# 7    Management                  15
# 8    Humanities                   8
# 9           Law                   7

# %%
# plotting a pie chart for the data calculated in the above mentioned snippet
course_data.iplot(kind='pie',labels='course',values='Number of students',title="Course Distribution")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="faca9b6e-41c4-4f47-84cb-4b29d2630d41" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("faca9b6e-41c4-4f47-84cb-4b29d2630d41")) {                    Plotly.newPlot(                        "faca9b6e-41c4-4f47-84cb-4b29d2630d41",                        [{"labels":["IT","Data Science","Engineering","Medical","Mathematics","Psychology","Pharmacy","Management","Humanities","Law"],"marker":{"colors":["rgba(255, 153, 51, 1.0)","rgba(55, 128, 191, 1.0)","rgba(50, 171, 96, 1.0)","rgba(128, 0, 128, 1.0)","rgba(219, 64, 82, 1.0)","rgba(0, 128, 128, 1.0)","rgba(255, 255, 51, 1.0)","rgba(128, 128, 0, 1.0)","rgba(251, 128, 114, 1.0)","rgba(128, 177, 211, 1.0)"]},"name":"","values":[61,52,42,34,31,25,23,15,8,7],"type":"pie"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","titlefont":{"color":"#4D5663"},"title":"Course Distribution"},                        {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('faca9b6e-41c4-4f47-84cb-4b29d2630d41');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %% [markdown]
# ### **Creating a new column by merging existing columns(depression,anxiety,panic attack) and plotting its distribution**

# %%
data.loc[(data["Depression"]=="Yes") | (data["Anxiety"]=="Yes") | (data["Panic Attack"]=="Yes"),'Mental Health Issues']= 'Yes'
data.loc[(data["Depression"]=="No") & (data["Anxiety"]=="No") & (data["Panic Attack"]=="No"),'Mental Health Issues']= 'No'
data
# Out:
#      Gender   Age       Course  Year  CGPA Married Depression Anxiety  \
# 0    Female  18.0  Engineering     1   7.0      No        Yes      No
# 1      Male  21.0     Pharmacy     2   8.0      No         No     Yes
# 2      Male  19.0           IT     1   4.0      No        Yes     Yes
# 3    Female  22.0          Law     3   5.0     Yes        Yes      No
# 4      Male  23.0  Mathematics     4   8.0      No         No      No
# ..      ...   ...          ...   ...   ...     ...        ...     ...
# 298  Female  27.0     Pharmacy     2   7.0     Yes         No     Yes
# 299  Female  26.0   Psychology     2   8.0     Yes        Yes      No
# 300  Female  21.0     Pharmacy     2   9.0      No         No      No
# 301  Female  23.0  Mathematics     3   6.0      No        Yes      No
# 302    Male  28.0   Psychology     2   7.0     Yes         No     Yes
#
#     Panic Attack Seeking Treatment Mental Health Issues
# 0            Yes                No                  Yes
# 1             No                No                  Yes
# 2            Yes                No                  Yes
# 3             No                No                  Yes
# 4             No                No                   No
# ..           ...               ...                  ...
# 298          Yes               Yes                  Yes
# 299           No               Yes                  Yes
# 300           No                No                   No
# 301          Yes               Yes                  Yes
# 302          Yes               Yes                  Yes
#
# [298 rows x 11 columns]

# %%
# Calculating number of students with and without mental health issues
mhi = data['Mental Health Issues'].value_counts()
mhi_data = pd.DataFrame({'mhi':mhi.index , 'Number of students':mhi.values})

# plotting pie chart for the mental health issue data
mhi_data.iplot(kind='pie',labels='mhi',values='Number of students',title="Distribution of Mental Health Status",hole=0.35)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="43357393-3098-4b16-b5b7-dc7e6c72d26a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("43357393-3098-4b16-b5b7-dc7e6c72d26a")) {                    Plotly.newPlot(                        "43357393-3098-4b16-b5b7-dc7e6c72d26a",                        [{"hole":0.35,"labels":["Yes","No"],"marker":{"colors":["rgba(255, 153, 51, 1.0)","rgba(55, 128, 191, 1.0)"]},"name":"","values":[185,113],"type":"pie"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","titlefont":{"color":"#4D5663"},"title":"Distribution of Mental Health Status"},                        {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('43357393-3098-4b16-b5b7-dc7e6c72d26a');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %% [markdown]
# ### **Gender-wise Distribution of Mental Health Issues**

# %%
# DataFrame of male students 
data_male_mhi = data[data['Gender'] == 'Male']

# DataFrame of female students 
data_female_mhi = data[data['Gender'] == 'Female']

#plotting pie charts for the data
myexplode = (0.025,0.025)
labels1 = ["Male \n With Mental Health Issue","Male \nWithout Mental Health Issue"]
labels2 = ["Female \nWith Mental Health Issue","Female \nWithout Mental Health Issue"]
fig, (ax1, ax2) = plt.subplots(1,2,figsize = (15,15))

# pie chart for checking mental health of male
ax1.pie(data_male_mhi['Mental Health Issues'].value_counts(),autopct="%1.1f%%",labels=labels1,explode = myexplode)

# pie chart for checking mental health of female
ax2.pie(data_female_mhi['Mental Health Issues'].value_counts(),autopct="%1.1f%%",labels=labels2,explode = myexplode)
plt.show()

# %% [markdown]
# ### **CGPA-wise Distribution of Mental Health Issue of students**

# %%
plt.figure(figsize=(10,10))
sns.set_theme(style="darkgrid")
ax = sns.countplot(x='CGPA',hue='Mental Health Issues',data=data)
plt.title("CGPA-wise Mental Health Issue Distribution")
plt.show()

# %% [markdown]
# ### **Mental Health Issues grouped by Course plotted in a horizontal bar chart**

# %%
# Creating a series where the count of student's Mental Health Issues is grouped by Course
mhi_yes = data[data["Mental Health Issues"] == 'Yes']
mhi_no = data[data["Mental Health Issues"] == 'No']
mhi_no_course = mhi_no.groupby("Course")["Mental Health Issues"].count()
mhi_yes_course = mhi_yes.groupby("Course")["Mental Health Issues"].count()

#Sorting from highest to lowest
mhi_no_course = mhi_no_course.sort_values(ascending = False)
mhi_yes_course = mhi_yes_course.sort_values(ascending = False)

# %%
#Creating a new dataframe after grouping
course_mhi = pd.concat([mhi_yes_course, mhi_no_course], axis=1)
course_mhi.columns.values[0] = "With Mental Health Issues"
course_mhi.columns.values[1] = "Without Mental Health Issues"
course_mhi
# Out:
#               With Mental Health Issues  Without Mental Health Issues
# Course
# Data Science                         33                            19
# IT                                   33                            28
# Engineering                          21                            21
# Mathematics                          21                            10
# Psychology                           21                             4
# Medical                              18                            16
# Pharmacy                             16                             7
# Management                           11                             4
# Law                                   6                             1
# Humanities                            5                             3

# %%
course_mhi['Total'] = course_mhi['With Mental Health Issues'] + course_mhi['Without Mental Health Issues']

# Sorting
course_mhi = course_mhi.sort_values(by=['Total'], ascending=False)
course_mhi
# Out:
#               With Mental Health Issues  Without Mental Health Issues  Total
# Course
# IT                                   33                            28     61
# Data Science                         33                            19     52
# Engineering                          21                            21     42
# Medical                              18                            16     34
# Mathematics                          21                            10     31
# Psychology                           21                             4     25
# Pharmacy                             16                             7     23
# Management                           11                             4     15
# Humanities                            5                             3      8
# Law                                   6                             1      7

# %%
course_mhi = course_mhi.reset_index(level=0)
course_mhi
# Out:
#          Course  With Mental Health Issues  Without Mental Health Issues  \
# 0            IT                         33                            28
# 1  Data Science                         33                            19
# 2   Engineering                         21                            21
# 3       Medical                         18                            16
# 4   Mathematics                         21                            10
# 5    Psychology                         21                             4
# 6      Pharmacy                         16                             7
# 7    Management                         11                             4
# 8    Humanities                          5                             3
# 9           Law                          6                             1
#
#    Total
# 0     61
# 1     52
# 2     42
# 3     34
# 4     31
# 5     25
# 6     23
# 7     15
# 8      8
# 9      7

# %%
# Sorting data for the plot
course_mhi = course_mhi.sort_values(by=['Total'], ascending=True)

# plotting horizontal bar chart for the data
ax = course_mhi.plot(x="Course", y="With Mental Health Issues", kind="barh", color = 'orange')

course_mhi.plot(x="Course", y="Without Mental Health Issues", kind="barh", ax=ax, color = 'steelblue')

# %% [markdown]
# ### **Year wise distribution of MHI of students**

# %%
plt.figure(figsize=(10,10))
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="Year", hue="Mental Health Issues", data=data)
plt.title("Year-wise Mental Health Issue Distribution")
plt.show()

# %% [markdown]
# ### **Course and Year-wise Mental Health Issue Distribution by contingency table**

# %%
# Contingency table for year and course data
data_mhi = data[data['Mental Health Issues'] == 'Yes']
data_mhi_table = pd.crosstab(data_mhi['Year'], data_mhi['Course'],margins = True)
data_mhi_table
# Out:
# Course  Data Science  Engineering  Humanities  IT  Law  Management  \
# Year
# 1                 20            9           2  14    0           3
# 2                  7            5           2  10    2           3
# 3                  4            3           1   4    4           4
# 4                  2            4           0   5    0           0
# 5                  0            0           0   0    0           1
# All               33           21           5  33    6          11
#
# Course  Mathematics  Medical  Pharmacy  Psychology  All
# Year
# 1                 3        8         2           7   68
# 2                 9        5         4           8   55
# 3                 6        1         6           4   37
# 4                 2        3         4           2   22
# 5                 1        1         0           0    3
# All              21       18        16          21  185

# %% [markdown]
# ### **Marital Status and Gender-wise distribution of Mental Health Issues**

# %%
# DataFrame of male students having mental health issues
data_male_mhi = data_male_mhi[data_male_mhi['Mental Health Issues'] == 'Yes']

# DataFrame of female students having mental health issues
data_female_mhi = data_female_mhi[data_female_mhi['Mental Health Issues'] == 'Yes']

#plotting pie charts for the data
myexplode = (0.025,0.025)
labels1 = ["Unmarried Male","Married Male"]
labels2 = ["Unmarried Female","Married Female"]
fig, (ax1, ax2) = plt.subplots(1,2,figsize = (15,15))

# pie chart for checking marital status wise mental health of male
ax1.pie(data_male_mhi['Married'].value_counts(),autopct="%1.1f%%",labels=labels1,explode = myexplode)

# pie chart for checking marital status wise mental health of female
ax2.pie(data_female_mhi['Married'].value_counts(),autopct="%1.1f%%",labels=labels2,explode = myexplode)
plt.show()

# %% [markdown]
# ### **Comparing anxiety,depression and panic attack using individual pie charts simultaneously**

# %%
myexplode = (0.025,0.025)
labels1 = ["No Depression","Depression"]
labels2 = ["No Anxiety","Anxiety"]
labels3 = ["No Panic Attack","Panic Attack"]
fig, (ax1, ax2, ax3) = plt.subplots(1,3,figsize = (20,15))

#pie chart for depression distribution
ax1.pie(data['Depression'].value_counts(),autopct="%1.1f%%",labels=labels1,explode = myexplode)
#pie chart for anxiety distribution
ax2.pie(data['Anxiety'].value_counts(),autopct="%1.1f%%",labels=labels2,explode = myexplode)
#pie chart for panic attack distribution
ax3.pie(data['Panic Attack'].value_counts(),autopct="%1.1f%%",labels=labels3,explode = myexplode)
plt.show()

# %% [markdown]
# ### **Comparing Anxiety, Depression and Panic Attack (using venn diagram)**

# %%
# Calculating data for plotting a Venn diagram

# Counting people with only anxiety
data['count']=0
data.loc[(data["Depression"]=="No") & (data["Anxiety"]=="Yes") & (data["Panic Attack"]=="No"),'count']= 1
anxiety=data['count'].value_counts()[1]
print("Anxiety =",anxiety)

# Counting people with only depression
data['count']=0
data.loc[(data["Depression"]=="Yes") & (data["Anxiety"]=="No") & (data["Panic Attack"]=="No"),'count']= 1
depression=data['count'].value_counts()[1]
print("Depression =",depression)

# Counting people with only panic attack
data['count']=0
data.loc[(data["Depression"]=="No") & (data["Anxiety"]=="No") & (data["Panic Attack"]=="Yes"),'count']= 1
panic_attack=data['count'].value_counts()[1]
print("Panic Attack =",panic_attack)

# Counting people with depression and anxiety
data['count']=0
data.loc[(data["Depression"]=="Yes") & (data["Anxiety"]=="Yes") & (data["Panic Attack"]=="No"),'count']= 1
anxiety_depression=data['count'].value_counts()[1]
print("Anxiety - Depression =",anxiety_depression)

# Counting people with depression and panic attack
data['count']=0
data.loc[(data["Depression"]=="Yes") & (data["Anxiety"]=="No") & (data["Panic Attack"]=="Yes"),'count']= 1
depression_panicattack=data['count'].value_counts()[1]
print("Depression - Panic Attack =",depression_panicattack)

# Counting people with anxiety and panic attack
data['count']=0
data.loc[(data["Depression"]=="No") & (data["Anxiety"]=="Yes") & (data["Panic Attack"]=="Yes"),'count']= 1
anxiety_panicattack=data['count'].value_counts()[1]
print("Anxiety - Panic Attack =",anxiety_panicattack)

# Counting people with anxiety, depression and panic attack
data['count']=0
data.loc[(data["Depression"]=="Yes") & (data["Anxiety"]=="Yes") & (data["Panic Attack"]=="Yes"),'count']= 1
anxiety_depression_panicattack=data['count'].value_counts()[1]
print("Anxiety - Depression - Panic Attack =",anxiety_depression_panicattack)

data=data.drop(['count'], axis=1)
# Out:
# Anxiety = 57
# Depression = 20
# Panic Attack = 15
# Anxiety - Depression = 26
# Depression - Panic Attack = 17
# Anxiety - Panic Attack = 20
# Anxiety - Depression - Panic Attack = 30

# %%
# importing required modules
from matplotlib_venn import venn3, venn3_circles
from matplotlib import pyplot as plt
  
# depict venn diagram
venn3(subsets=(anxiety,depression,anxiety_depression,panic_attack,anxiety_panicattack,depression_panicattack,anxiety_depression_panicattack), 
      set_labels=('Anxiety', 'Depression', 'Panic Attack'), 
      set_colors=("orange", "blue", "red"), alpha=0.7)
  
# outline of circle line style and width
venn3_circles(subsets=(anxiety,depression,anxiety_depression,panic_attack,anxiety_panicattack,depression_panicattack,anxiety_depression_panicattack),
              linestyle="dashed", linewidth=1)
  
# title of the venn diagram
plt.title("Anxiety - Depression - Panic Attack Evaluation")
plt.show()

# %% [markdown]
# ### **Comparing MHI of students on the basis of average CGPA**

# %%
# calculating average cgpa
avgCGPA=data['CGPA'].mean()

# adding a column to the dataset which states if a student has above average or below average CGPA
data['avg_CGPA']='Above Average'
data.loc[(data["CGPA"]<avgCGPA),'avg_CGPA']= 'Below Average'

data
# Out:
#      Gender   Age       Course  Year  CGPA Married Depression Anxiety  \
# 0    Female  18.0  Engineering     1   7.0      No        Yes      No
# 1      Male  21.0     Pharmacy     2   8.0      No         No     Yes
# 2      Male  19.0           IT     1   4.0      No        Yes     Yes
# 3    Female  22.0          Law     3   5.0     Yes        Yes      No
# 4      Male  23.0  Mathematics     4   8.0      No         No      No
# ..      ...   ...          ...   ...   ...     ...        ...     ...
# 298  Female  27.0     Pharmacy     2   7.0     Yes         No     Yes
# 299  Female  26.0   Psychology     2   8.0     Yes        Yes      No
# 300  Female  21.0     Pharmacy     2   9.0      No         No      No
# 301  Female  23.0  Mathematics     3   6.0      No        Yes      No
# 302    Male  28.0   Psychology     2   7.0     Yes         No     Yes
#
#     Panic Attack Seeking Treatment Mental Health Issues       avg_CGPA
# 0            Yes                No                  Yes  Below Average
# 1             No                No                  Yes  Above Average
# 2            Yes                No                  Yes  Below Average
# 3             No                No                  Yes  Below Average
# 4             No                No                   No  Above Average
# ..           ...               ...                  ...            ...
# 298          Yes               Yes                  Yes  Below Average
# 299           No               Yes                  Yes  Above Average
# 300           No                No                   No  Above Average
# 301          Yes               Yes                  Yes  Below Average
# 302          Yes               Yes                  Yes  Below Average
#
# [298 rows x 12 columns]

# %%
avgCGPA
# Out:
# 7.090604026845638

# %%
# Contingency table for gender and awareness (seeking treatment)
data_mhi_cgpa_table = pd.crosstab(data['avg_CGPA'], data['Mental Health Issues'],margins = True)
data_mhi_cgpa_table
# Out:
# Mental Health Issues   No  Yes  All
# avg_CGPA
# Above Average          70   77  147
# Below Average          43  108  151
# All                   113  185  298

# %%
# DataFrame of above average students 
data_above_avg = data[data['avg_CGPA'] == 'Above Average']

# DataFrame of below average students 
data_below_avg = data[data['avg_CGPA'] == 'Below Average']

myexplode = (0.025,0.025)
labels1 = ["Above Average Students with MHI","Above Average Students without MHI"]
labels2 = ["Below Average Students with MHI","Below Average Students without MHI"]
fig, (ax1, ax2) = plt.subplots(1,2,figsize = (15,15))

# pie chart for checking mental health issue of above average students
ax1.pie(data_above_avg['Mental Health Issues'].value_counts(),autopct="%1.1f%%",labels=labels1,explode = myexplode)

# pie chart for checking mental health issue of below average students
ax2.pie(data_below_avg['Mental Health Issues'].value_counts(),autopct="%1.1f%%",labels=labels2,explode = myexplode)
plt.show()

# %% [markdown]
# ### **CGPA and Gender-wise Distribution of students having MHI**

# %%
fig, ax =plt.subplots(1,2,figsize=(10,8))
# plotting a countplot for above average students having mental health issues with respect to the gender
sns.countplot(x='Gender',hue='Mental Health Issues',data=data_above_avg,ax=ax[0]).set(title="Above Average Students")
# plotting a countplot for below average students having mental health issues with respect to the gender
sns.countplot(x='Gender',hue='Mental Health Issues',data=data_below_avg,ax=ax[1]).set(title="Below Average Students")

fig.show()

# drop column ave_CGPA
data=data.drop(['avg_CGPA'], axis=1)

# %% [markdown]
# ### **Checking distribution for awareness of students regarding MHI**

# %%
# Counting students that have mental health issues and are seeking treatment
awareness = data_mhi['Seeking Treatment'].value_counts()
awareness_data = pd.DataFrame({'Seeking Treatment':awareness.index , 'Number of students':awareness.values})
awareness_data.iplot(kind='pie',labels='Seeking Treatment',values='Number of students',title="Distribution of Students Seeking Help",hole=0.35)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="df06b2c0-c3a8-4796-9476-57862b892a31" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("df06b2c0-c3a8-4796-9476-57862b892a31")) {                    Plotly.newPlot(                        "df06b2c0-c3a8-4796-9476-57862b892a31",                        [{"hole":0.35,"labels":["No","Yes"],"marker":{"colors":["rgba(255, 153, 51, 1.0)","rgba(55, 128, 191, 1.0)"]},"name":"","values":[139,46],"type":"pie"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","titlefont":{"color":"#4D5663"},"title":"Distribution of Students Seeking Help"},                        {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('df06b2c0-c3a8-4796-9476-57862b892a31');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %% [markdown]
# ### **Comparing the distribution of male and female seeking help from a specialist**

# %%
# Contingency table for gender and awareness (seeking treatment)
data_mhi_gender_table = pd.crosstab(data_mhi['Gender'], data_mhi['Seeking Treatment'],margins = True)
data_mhi_gender_table
# Out:
# Seeking Treatment   No  Yes  All
# Gender
# Female              88   24  112
# Male                51   22   73
# All                139   46  185

# %%
#plotting pie charts for male and female who suffer from mental health issues with respect to their awareness about MHI
myexplode = (0.025,0.025)
labels1 = ["Male Not Seeking Treatment","Male Seeking Treatment"]
labels2 = ["Female Not Seeking Treatment","Female Seeking Treatment"]
fig, (ax1, ax2) = plt.subplots(1,2,figsize = (15,15))

# pie chart for checking percentage of male who are facing mental health issues and are seeking treatment
ax1.pie(data_male_mhi['Seeking Treatment'].value_counts(),autopct="%1.1f%%",labels=labels1,explode = myexplode)

# pie chart for checking percentage of female who are facing mental health issues and are seeking treatment
ax2.pie(data_female_mhi['Seeking Treatment'].value_counts(),autopct="%1.1f%%",labels=labels2,explode = myexplode)
plt.show()

# %% [markdown]
# ### **Showing correlation between various columns/fields using heatmap**

# %%
# converting the categorical data to numerical data for deriving correlation
data['d']=0
data.loc[(data["Depression"]=="Yes"),'d']= 1
data['a']=0
data.loc[(data["Anxiety"]=="Yes"),'a']= 1
data['p']=0
data.loc[(data["Panic Attack"]=="Yes"),'p']= 1
data['m']=0
data.loc[(data["Mental Health Issues"]=="Yes"),'m']=1
data
# Out:
#      Gender   Age       Course  Year  CGPA Married Depression Anxiety  \
# 0    Female  18.0  Engineering     1   7.0      No        Yes      No
# 1      Male  21.0     Pharmacy     2   8.0      No         No     Yes
# 2      Male  19.0           IT     1   4.0      No        Yes     Yes
# 3    Female  22.0          Law     3   5.0     Yes        Yes      No
# 4      Male  23.0  Mathematics     4   8.0      No         No      No
# ..      ...   ...          ...   ...   ...     ...        ...     ...
# 298  Female  27.0     Pharmacy     2   7.0     Yes         No     Yes
# 299  Female  26.0   Psychology     2   8.0     Yes        Yes      No
# 300  Female  21.0     Pharmacy     2   9.0      No         No      No
# 301  Female  23.0  Mathematics     3   6.0      No        Yes      No
# 302    Male  28.0   Psychology     2   7.0     Yes         No     Yes
#
#     Panic Attack Seeking Treatment Mental Health Issues  d  a  p  m
# 0            Yes                No                  Yes  1  0  1  1
# 1             No                No                  Yes  0  1  0  1
# 2            Yes                No                  Yes  1  1  1  1
# 3             No                No                  Yes  1  0  0  1
# 4             No                No                   No  0  0  0  0
# ..           ...               ...                  ... .. .. .. ..
# 298          Yes               Yes                  Yes  0  1  1  1
# 299           No               Yes                  Yes  1  0  0  1
# 300           No                No                   No  0  0  0  0
# 301          Yes               Yes                  Yes  1  0  1  1
# 302          Yes               Yes                  Yes  0  1  1  1
#
# [298 rows x 15 columns]

# %%
# deriving correlation
df_corr=data.corr()
df_corr
# Out:
#            Age      Year      CGPA         d         a         p         m
# Age   1.000000  0.223384  0.049247 -0.019642 -0.004819 -0.013033  0.039915
# Year  0.223384  1.000000 -0.000127  0.021620 -0.030766 -0.028827  0.005438
# CGPA  0.049247 -0.000127  1.000000 -0.233525 -0.014590 -0.134037 -0.239013
# d    -0.019642  0.021620 -0.233525  1.000000  0.211153  0.347191  0.526402
# a    -0.004819 -0.030766 -0.014590  0.211153  1.000000  0.202585  0.701677
# p    -0.013033 -0.028827 -0.134037  0.347191  0.202585  1.000000  0.481541
# m     0.039915  0.005438 -0.239013  0.526402  0.701677  0.481541  1.000000

# %%
# plotting a heatmap for the correlation derived from the above snippet
fig, ax = plt.subplots(figsize=(8,8))         
ax = sns.heatmap(df_corr,annot=True,linewidth=0.5)
